# %% [markdown]
# # Modelo para auxilio no diagnóstico de Pneumunia.

# %% [markdown]
# ###ResNet152V2

# %% [markdown]
# ## Importando e carregando bibliotecas básica

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from imutils import paths

# %% [markdown]
# ## Criação da constantes do modelo

# %%
INIT_LR = 1e-3
EPOCHS = 15
BS = 40
np.random.seed(0)

# %% [markdown]
# ## Carrega e tratamento inicial do dataset

# %%
from google.colab import drive
import os

drive.mount('/content/drive')
workdir_path = '/content/drive/My Drive/TCC_IMAGENS'
os.chdir(workdir_path)
# Out:
# Mounted at /content/drive

# %%
from imutils import paths

dataset_path = 'dataset_imagens'
imagens_raioX  = list(paths.list_images(dataset_path))

# %%
#Tratamento das imagens, criação e carga das listas de imagens e labels
import cv2

imagens = []
labels = []

for imagem in imagens_raioX:

    label = imagem.split(os.path.sep)[-2]

   # Faz tratemento nos canais de cores das imagens e padroniza
   # o tamnho em 224 x 224
    imagem = cv2.imread(imagem)
    imagem = cv2.cvtColor(imagem, cv2.COLOR_BGR2RGB)
    imagem = cv2.resize(imagem, (224, 224))

    imagens.append(imagem)
    labels.append(label)

# %% [markdown]
# ## Análise exploratória

# %% [markdown]
# ### Verificando o balanceomento do dataset

# %%
# Criua e carrega os dados quantitaivis da lista de imagens em um
# dicionario de dados para análise quantitativa das imagens

import matplotlib.pyplot as plt

dados = {'NORMAL': labels.count('NORMAL'), 'PNEUMONIA_BACTERIANA':labels.count('PNEUMONIA_BACTERIANA'), 'PNEUMONIA_VIRAL':labels.count('PNEUMONIA_VIRAL') }
plt.figure()
plt.bar(dados.keys(), dados.values())
plt.show()

# %% [markdown]
# ### Preparando e visualizando imagem

# %%
# Converte as lista em matrizes, padronizando a escala de pixel na escala de
# [0, 255]

imagens_N = np.array(imagens) / 255.0
labels_N = np.array(labels)

# %%
plt.figure(figsize=(5, 5))
plt.imshow(imagens_N[labels_N =='NORMAL'][1])
plt.show()

# %% [markdown]
# ## Transformando os labels para numeral

# %%
from keras.utils import to_categorical
from sklearn.preprocessing import LabelBinarizer
from sklearn.preprocessing import StandardScaler

lb = LabelBinarizer()
labels_b = lb.fit_transform(labels_N)

# %% [markdown]
# ### Separação dos dados de treino, teste.

# %%
from sklearn.model_selection import train_test_split

(trainX, testX, trainY, testY) = train_test_split(imagens_N, labels_b, test_size=0.20, stratify=labels_b, random_state=42)

# %% [markdown]
# ## Rede Neural

# %% [markdown]
# ### Importando e configurando a rede VGG16

# %%
from tensorflow.keras.applications import ResNet152V2
from tensorflow.keras.layers import Input

baseModel = ResNet152V2 (weights="imagenet", include_top=False,
                  input_tensor = Input(shape=(224, 224, 3)))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet152v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 234545216/234545216 ━━━━━━━━━━━━━━━━━━━━ 12s 0us/step

# %% [markdown]
# ### Definindo a camadade Saida FC

# %%
# Construindo a camada FC
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras.layers import AveragePooling2D

headModel = baseModel.output
headModel = AveragePooling2D(pool_size=(4, 4))(headModel)
headModel = Flatten(name="flatten")(headModel)
headModel = Dense(256, activation="relu")(headModel)
headModel = Dropout(0.5)(headModel)
headModel = Dense(128, activation="relu")(headModel)
headModel = Dropout(0.4)(headModel)
headModel = Dense(64, activation="relu")(headModel)
headModel = Dense(3, activation="softmax")(headModel)

# %% [markdown]
# ### Montado a rede

# %%
model = Model(inputs=baseModel.input, outputs=headModel)

# %% [markdown]
# ### Carregando e compilando o modelo

# %%
from tensorflow.keras.optimizers import Adam

for layer in baseModel.layers:
    layer.trainable = False

print("[INFO] compilando o modelo...")
opt = Adam(learning_rate=INIT_LR, weight_decay=INIT_LR / EPOCHS )
model.compile(loss="binary_crossentropy", optimizer=opt,
              metrics=["accuracy"])
# Out:
# [INFO] compilando o modelo...

# %% [markdown]
# ### Verificando as saída da camada convolucional

# %%
#baseModel = InceptionV3(weights="imagenet", include_top=False,
                  #input_tensor=Input(shape=(224, 224, 3)))

f1 = baseModel.layers[1].output
f2 = baseModel.layers[2].output
f3 = baseModel.layers[4].output
f4 = baseModel.layers[5].output
feature_maps = Model(inputs=baseModel.input, outputs=[f1, f2, f3, f4])

# %%
y = np.argmax(trainY, axis=-1)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import AveragePooling2D

feat1, feat2, feat3, feat4 = feature_maps.predict(trainX[y==1][0:1])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step

# %%
fig, axs = plt.subplots(2, 2, figsize=(10, 10))
axs[0, 0].imshow(feat1[0, :, :, 0:3])
axs[0, 1].imshow(feat2[0, :, :, 6:9])
axs[1, 0].imshow(feat3[0, :, :, 0:3])
axs[1, 1].imshow(feat4[0, :, :, 3:6])
plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ### Trainando a FC

# %%
print("[INFO] Trainando a FC...")
h = model.fit(trainX,
              trainY,
              batch_size = BS,
              steps_per_epoch=len(trainX) // BS,
              validation_split=0.2,
              epochs=EPOCHS)
# Out:
# [INFO] Trainando a FC...
# Epoch 1/15
# 25/32 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.4465 - loss: 0.6350
# /usr/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 508ms/step - accuracy: 0.4687 - loss: 0.6183 - val_accuracy: 0.7346 - val_loss: 0.3957
# Epoch 2/15
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.7296 - loss: 0.4109 - val_accuracy: 0.7577 - val_loss: 0.3429
# Epoch 3/15
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.7799 - loss: 0.3389 - val_accuracy: 0.7654 - val_loss: 0.3427
# Epoch 4/15
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.8256 - loss: 0.2752 - val_accuracy: 0.7577 - val_loss: 0.3312
# Epoch 5/15
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.8404 - loss: 0.2616 - val_accuracy: 0.7731 - val_loss: 0.3344
# Epoch 6/15
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.8505 - loss: 0.2132 - val_accuracy: 0.7923 - val_loss: 0.3848
# Epoch 7/15
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.8855 - loss: 0.1965 - val_accuracy: 0.7769 - val_loss: 0.3695
# Epoch 8/15
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9065 - loss: 0.1737 - val_accuracy: 0.7769 - val_loss: 0.3622
# Epoch 9/15
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9033 - loss: 0.1485 - val_accuracy: 0.7962 - val_loss: 0.3985
# Epoch 10/15
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9246 - loss: 0.1154 - val_accuracy: 0.8000 - val_loss: 0.3712
# Epoch 11/15
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9293 - loss: 0.1206 - val_accuracy: 0.7885 - val_loss: 0.4530
# Epoch 12/15
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9314 - loss: 0.1087 - val_accuracy: 0.7923 - val_loss: 0.4382
# Epoch 13/15
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9453 - loss: 0.0917 - val_accuracy: 0.8000 - val_loss: 0.4443
# Epoch 14/15
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9602 - loss: 0.0694 - val_accuracy: 0.7808 - val_loss: 0.4894
# Epoch 15/15
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9734 - loss: 0.0562 - val_accuracy: 0.7962 - val_loss: 0.5115

# %% [markdown]
# ## Analisando a performance do modelo

# %%
score = model.evaluate(testX, testY, verbose=0)

print('Test accuracy:', score[1])
# Out:
# Test accuracy: 0.8676922917366028

# %%
h.history.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
import seaborn as sns

print("[INFO] Avaliando a Rede...")
predIdxs = model.predict(testX, batch_size=BS)

predIdxs = np.argmax(predIdxs, axis=1)

print(classification_report(testY.argmax(axis=1), predIdxs,
                            target_names=lb.classes_))

cm = confusion_matrix(testY.argmax(axis=1), predIdxs)
total = sum(sum(cm))
acc = (cm[0, 0] + cm[1, 1]) / total
sensitivity = cm[0, 0] / (cm[0, 0] + cm[0, 1])
specificity = cm[1, 1] / (cm[1, 0] + cm[1, 1])
# Out:
# [INFO] Avaliando a Rede...
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step
#                       precision    recall  f1-score   support
#
#               NORMAL       0.93      0.97      0.95       100
# PNEUMONIA_BACTERIANA       0.80      0.82      0.81       100
#      PNEUMONIA_VIRAL       0.87      0.82      0.84       125
#
#             accuracy                           0.87       325
#            macro avg       0.87      0.87      0.87       325
#         weighted avg       0.87      0.87      0.87       325

# %% [markdown]
# ### Gráficos: Loss, Accuracy e validação

# %%
import matplotlib.pyplot as plt

plt.plot(h.history['loss'], label='train')
plt.plot(h.history['val_loss'], label='valid')
plt.title("Loss no treino Pneumunia Dataset")
plt.ylabel('loss')
plt.xlabel('época')
plt.legend()
plt.show()

# %%
plt.plot(h.history['accuracy'], label='train')
plt.plot(h.history['val_accuracy'], label='validation')
plt.title("Acurácia no treino Pneumunia Dataset")
plt.ylabel('acurácia')
plt.xlabel('época')
plt.legend()
plt.show()

# %%
import seaborn as sns
ax = plt.subplot()
sns.heatmap(cm, annot=True, fmt=".0f", cmap='YlGnBu')
plt.xlabel('Real')
plt.ylabel('Previsto')
plt.title('Matriz de Confusão')

# Colocar os nomes
ax.xaxis.set_ticklabels(['Normal', 'Bacteriana','Viral'])
ax.yaxis.set_ticklabels(['Normal', 'Bacteriana','Viral'])
plt.show()

# %% [markdown]
# # Modelo para auxilio no diagnóstico de Pneumunia.

# %% [markdown]
# ###DenseNet201

# %% [markdown]
# ## Importando e carregando bibliotecas básica

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from imutils import paths

# %% [markdown]
# ## Criação da constantes do modelo

# %%
INIT_LR = 1e-3
EPOCHS = 20
BS = 50
np.random.seed(0)

# %% [markdown]
# ## Carrega e tratamento inicial do dataset

# %%
from google.colab import drive
import os

drive.mount('/content/drive')
workdir_path = '/content/drive/My Drive/TCC_IMAGENS'
os.chdir(workdir_path)
# Out:
# Mounted at /content/drive

# %%
from imutils import paths

dataset_path = 'dataset_imagens'
imagens_raioX  = list(paths.list_images(dataset_path))

# %%
#Tratamento das imagens, criação e carga das listas de imagens e labels
import cv2

imagens = []
labels = []

for imagem in imagens_raioX:

    label = imagem.split(os.path.sep)[-2]

   # Faz tratemento nos canais de cores das imagens e padroniza
   # o tamnho em 224 x 224
    imagem = cv2.imread(imagem)
    imagem = cv2.cvtColor(imagem, cv2.COLOR_BGR2RGB)
    imagem = cv2.resize(imagem, (224, 224))

    imagens.append(imagem)
    labels.append(label)

# %% [markdown]
# ## Análise exploratória

# %% [markdown]
# ### Verificando o balanceomento do dataset

# %%
# Criua e carrega os dados quantitaivis da lista de imagens em um
# dicionario de dados para análise quantitativa das imagens

import matplotlib.pyplot as plt

dados = {'NORMAL': labels.count('NORMAL'), 'PNEUMONIA_BACTERIANA':labels.count('PNEUMONIA_BACTERIANA'), 'PNEUMONIA_VIRAL':labels.count('PNEUMONIA_VIRAL') }
plt.figure()
plt.bar(dados.keys(), dados.values())
plt.show()

# %% [markdown]
# ### Preparando e visualizando imagem

# %%
# Converte as lista em matrizes, padronizando a escala de pixel na escala de
# [0, 255]

imagens_N = np.array(imagens) / 255.0
labels_N = np.array(labels)

# %%
plt.figure(figsize=(5, 5))
plt.imshow(imagens_N[labels_N =='NORMAL'][1])
plt.show()

# %% [markdown]
# ## Transformando os labels para numeral

# %%
from keras.utils import to_categorical
from sklearn.preprocessing import LabelBinarizer
from sklearn.preprocessing import StandardScaler

lb = LabelBinarizer()
labels_b = lb.fit_transform(labels_N)

# %% [markdown]
# ### Separação dos dados de treino, teste.

# %%
from sklearn.model_selection import train_test_split

(trainX, testX, trainY, testY) = train_test_split(imagens_N, labels_b, test_size=0.20, stratify=labels_b, random_state=42)

# %% [markdown]
# ## Rede Neural

# %% [markdown]
# ### Importando e configurando a rede VGG16

# %%
from tensorflow.keras.applications import DenseNet201
from tensorflow.keras.layers import Input

baseModel = DenseNet201 (weights="imagenet", include_top=False,
                  input_tensor = Input(shape=(224, 224, 3)))

# %% [markdown]
# ### Definindo a camadade Saida FC

# %%
# Construindo a camada FC
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras.layers import AveragePooling2D

headModel = baseModel.output
headModel = AveragePooling2D(pool_size=(4, 4))(headModel)
headModel = Flatten(name="flatten")(headModel)
headModel = Dense(256, activation="relu")(headModel)
headModel = Dropout(0.5)(headModel)
headModel = Dense(128, activation="relu")(headModel)
headModel = Dropout(0.4)(headModel)
headModel = Dense(64, activation="relu")(headModel)
headModel = Dense(3, activation="softmax")(headModel)

# %% [markdown]
# ### Montado a rede

# %%
model = Model(inputs=baseModel.input, outputs=headModel)

# %% [markdown]
# ### Carregando e compilando o modelo

# %%
from tensorflow.keras.optimizers import Adam

for layer in baseModel.layers:
    layer.trainable = False

print("[INFO] compilando o modelo...")
opt = Adam(learning_rate=INIT_LR, weight_decay=INIT_LR / EPOCHS )
model.compile(loss="binary_crossentropy", optimizer=opt,
              metrics=["accuracy"])
# Out:
# [INFO] compilando o modelo...

# %% [markdown]
# ### Verificando as saída da camada convolucional

# %%
#baseModel = InceptionV3(weights="imagenet", include_top=False,
                  #input_tensor=Input(shape=(224, 224, 3)))

f1 = baseModel.layers[1].output
f2 = baseModel.layers[2].output
f3 = baseModel.layers[4].output
f4 = baseModel.layers[5].output
feature_maps = Model(inputs=baseModel.input, outputs=[f1, f2, f3, f4])

# %%
y = np.argmax(trainY, axis=-1)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import AveragePooling2D

feat1, feat2, feat3, feat4 = feature_maps.predict(trainX[y==1][0:1])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step

# %%
fig, axs = plt.subplots(2, 2, figsize=(10, 10))
axs[0, 0].imshow(feat1[0, :, :, 0:3])
axs[0, 1].imshow(feat2[0, :, :, 6:9])
axs[1, 0].imshow(feat3[0, :, :, 0:3])
axs[1, 1].imshow(feat4[0, :, :, 3:6])
plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ### Trainando a FC

# %%
print("[INFO] Trainando a FC...")
h = model.fit(trainX,
              trainY,
              batch_size = BS,
              steps_per_epoch=len(trainX) // BS,
              validation_split=0.2,
              epochs=EPOCHS)
# Out:
# [INFO] Trainando a FC...
# Epoch 1/20
# 21/26 ━━━━━━━━━━━━━━━━━━━━ 3s 722ms/step - accuracy: 0.5073 - loss: 0.6560
# /usr/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 98s 2s/step - accuracy: 0.5211 - loss: 0.6379 - val_accuracy: 0.7154 - val_loss: 0.3962
# Epoch 2/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.7291 - loss: 0.4030 - val_accuracy: 0.7615 - val_loss: 0.3568
# Epoch 3/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.7914 - loss: 0.3310 - val_accuracy: 0.7808 - val_loss: 0.3051
# Epoch 4/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.8240 - loss: 0.2782 - val_accuracy: 0.8115 - val_loss: 0.2876
# Epoch 5/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8388 - loss: 0.2675 - val_accuracy: 0.8192 - val_loss: 0.2733
# Epoch 6/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.8521 - loss: 0.2273 - val_accuracy: 0.8077 - val_loss: 0.2703
# Epoch 7/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.8755 - loss: 0.2039 - val_accuracy: 0.8231 - val_loss: 0.2668
# Epoch 8/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.8818 - loss: 0.2031 - val_accuracy: 0.8154 - val_loss: 0.2701
# Epoch 9/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.8651 - loss: 0.2021 - val_accuracy: 0.8346 - val_loss: 0.2733
# Epoch 10/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.8957 - loss: 0.1819 - val_accuracy: 0.8231 - val_loss: 0.2752
# Epoch 11/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9108 - loss: 0.1481 - val_accuracy: 0.8192 - val_loss: 0.2982
# Epoch 12/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9058 - loss: 0.1533 - val_accuracy: 0.8308 - val_loss: 0.2835
# Epoch 13/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9150 - loss: 0.1389 - val_accuracy: 0.8154 - val_loss: 0.3196
# Epoch 14/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9338 - loss: 0.1213 - val_accuracy: 0.8462 - val_loss: 0.3257
# Epoch 15/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9363 - loss: 0.1077 - val_accuracy: 0.8038 - val_loss: 0.3184
# Epoch 16/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9241 - loss: 0.1237 - val_accuracy: 0.8269 - val_loss: 0.3185
# Epoch 17/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9345 - loss: 0.1079 - val_accuracy: 0.8462 - val_loss: 0.3387
# Epoch 18/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9379 - loss: 0.0911 - val_accuracy: 0.8423 - val_loss: 0.3423
# Epoch 19/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9393 - loss: 0.0904 - val_accuracy: 0.8577 - val_loss: 0.3134
# Epoch 20/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.9508 - loss: 0.0757 - val_accuracy: 0.8192 - val_loss: 0.3730

# %% [markdown]
# ## Analisando a performance do modelo

# %%
score = model.evaluate(testX, testY, verbose=0)

print('Test accuracy:', score[1])
# Out:
# Test accuracy: 0.8399999737739563

# %%
h.history.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
import seaborn as sns

print("[INFO] Avaliando a Rede...")
predIdxs = model.predict(testX, batch_size=BS)

predIdxs = np.argmax(predIdxs, axis=1)

print(classification_report(testY.argmax(axis=1), predIdxs,
                            target_names=lb.classes_))

cm = confusion_matrix(testY.argmax(axis=1), predIdxs)
total = sum(sum(cm))
acc = (cm[0, 0] + cm[1, 1]) / total
sensitivity = cm[0, 0] / (cm[0, 0] + cm[0, 1])
specificity = cm[1, 1] / (cm[1, 0] + cm[1, 1])
# Out:
# [INFO] Avaliando a Rede...
# 5/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# WARNING:tensorflow:5 out of the last 17 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7ef0b838d000> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step
#                       precision    recall  f1-score   support
#
#               NORMAL       1.00      0.82      0.90       100
# PNEUMONIA_BACTERIANA       0.87      0.75      0.81       100
#      PNEUMONIA_VIRAL       0.75      0.94      0.83       125
#
#             accuracy                           0.84       325
#            macro avg       0.87      0.84      0.85       325
#         weighted avg       0.86      0.84      0.84       325

# %% [markdown]
# ### Gráficos: Loss, Accuracy e validação

# %%
import matplotlib.pyplot as plt

plt.plot(h.history['loss'], label='train')
plt.plot(h.history['val_loss'], label='valid')
plt.title("Loss no treino Pneumunia Dataset")
plt.ylabel('loss')
plt.xlabel('época')
plt.legend()
plt.show()

# %%
plt.plot(h.history['accuracy'], label='train')
plt.plot(h.history['val_accuracy'], label='validation')
plt.title("Acurácia no treino Pneumunia Dataset")
plt.ylabel('acurácia')
plt.xlabel('época')
plt.legend()
plt.show()

# %%
import seaborn as sns
ax = plt.subplot()
sns.heatmap(cm, annot=True, fmt=".0f", cmap='YlGnBu')
plt.xlabel('Real')
plt.ylabel('Previsto')
plt.title('Matriz de Confusão')

# Colocar os nomes
ax.xaxis.set_ticklabels(['Normal', 'Bacteriana','Viral'])
ax.yaxis.set_ticklabels(['Normal', 'Bacteriana','Viral'])
plt.show()
